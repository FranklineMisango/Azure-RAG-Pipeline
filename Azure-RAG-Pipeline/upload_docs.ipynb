# %% [markdown]
# ### IMPORTS

# %%
import os
import argparse
import glob
import html
import io
import re
import time
from pypdf import PdfReader, PdfWriter
from azure.identity import AzureDeveloperCliCredential
from azure.core.credentials import AzureKeyCredential
from azure.storage.blob import BlobServiceClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import *
from azure.search.documents import SearchClient
from azure.ai.formrecognizer import DocumentAnalysisClient

# %%
from config import *

# %%
search_creds = AzureKeyCredential(searchkey)
storage_creds = storagekey

# %%
print(search_creds)
print(storage_creds)
# Out:
# <azure.core.credentials.AzureKeyCredential object at 0x7f91da462b10>
# aF9oEdyjDKkTTO4oybovbCEfwQBhahFfSeFW3/BDWYFyQjSmtAad7Ol/5roW1wVeWvwAA/WAk5mN+AStZAsbdw==

# %%
MAX_SECTION_LENGTH = 1000
SENTENCE_SEARCH_LIMIT = 100
SECTION_OVERLAP = 100

# %% [markdown]
# ### FUNCTIONS

# %%
def blob_name_from_file_page(filename, page = 0):
    if os.path.splitext(filename)[1].lower() == ".pdf":
        return os.path.splitext(os.path.basename(filename))[0] + f"-{page}" + ".pdf"
    else:
        return os.path.basename(filename)

# %%
def upload_blobs(filename):
    blob_service = BlobServiceClient(account_url=f"https://{storageaccount}.blob.core.windows.net", credential=storage_creds)
    blob_container = blob_service.get_container_client(container)
    if not blob_container.exists():
        blob_container.create_container()

    # if file is PDF split into pages and upload each page as a separate blob
    if os.path.splitext(filename)[1].lower() == ".pdf":
        reader = PdfReader(filename)
        pages = reader.pages
        for i in range(len(pages)):
            blob_name = blob_name_from_file_page(filename, i)
            if verbose: print(f"\tUploading blob for page {i} -> {blob_name}")
            f = io.BytesIO()
            writer = PdfWriter()
            writer.add_page(pages[i])
            writer.write(f)
            f.seek(0)
            blob_container.upload_blob(blob_name, f, overwrite=True)
    else:
        blob_name = blob_name_from_file_page(filename)
        with open(filename,"rb") as data:
            blob_container.upload_blob(blob_name, data, overwrite=True)


def table_to_html(table):
    table_html = "<table>"
    rows = [sorted([cell for cell in table.cells if cell.row_index == i], key=lambda cell: cell.column_index) for i in range(table.row_count)]
    for row_cells in rows:
        table_html += "<tr>"
        for cell in row_cells:
            tag = "th" if (cell.kind == "columnHeader" or cell.kind == "rowHeader") else "td"
            cell_spans = ""
            if cell.column_span > 1: cell_spans += f" colSpan={cell.column_span}"
            if cell.row_span > 1: cell_spans += f" rowSpan={cell.row_span}"
            table_html += f"<{tag}{cell_spans}>{html.escape(cell.content)}</{tag}>"
        table_html +="</tr>"
    table_html += "</table>"
    return table_html

def get_document_text(filename):
    offset = 0
    page_map = []
    if localpdfparser:
        reader = PdfReader(filename)
        pages = reader.pages
        for page_num, p in enumerate(pages):
            page_text = p.extract_text()
            page_map.append((page_num, offset, page_text))
            offset += len(page_text)
    else:
        if verbose: print(f"Extracting text from '{filename}' using Azure Form Recognizer")
        form_recognizer_client = DocumentAnalysisClient(endpoint=f"https://{formrecognizerservice}.cognitiveservices.azure.com/", credential=formrecognizer_creds, headers={"x-ms-useragent": "azure-search-chat-demo/1.0.0"})
        with open(filename, "rb") as f:
            poller = form_recognizer_client.begin_analyze_document("prebuilt-layout", document = f)
        form_recognizer_results = poller.result()

        for page_num, page in enumerate(form_recognizer_results.pages):
            tables_on_page = [table for table in form_recognizer_results.tables if table.bounding_regions[0].page_number == page_num + 1]

            # mark all positions of the table spans in the page
            page_offset = page.spans[0].offset
            page_length = page.spans[0].length
            table_chars = [-1]*page_length
            for table_id, table in enumerate(tables_on_page):
                for span in table.spans:
                    # replace all table spans with "table_id" in table_chars array
                    for i in range(span.length):
                        idx = span.offset - page_offset + i
                        if idx >=0 and idx < page_length:
                            table_chars[idx] = table_id

            # build page text by replacing charcters in table spans with table html
            page_text = ""
            added_tables = set()
            for idx, table_id in enumerate(table_chars):
                if table_id == -1:
                    page_text += form_recognizer_results.content[page_offset + idx]
                elif not table_id in added_tables:
                    page_text += table_to_html(tables_on_page[table_id])
                    added_tables.add(table_id)

            page_text += " "
            page_map.append((page_num, offset, page_text))
            offset += len(page_text)

    return page_map

# %%
def split_text(page_map):
    SENTENCE_ENDINGS = [".", "!", "?"]
    WORDS_BREAKS = [",", ";", ":", " ", "(", ")", "[", "]", "{", "}", "\t", "\n"]
    if verbose: print(f"Splitting text into sections")

    def find_page(offset):
        l = len(page_map)
        for i in range(l - 1):
            if offset >= page_map[i][1] and offset < page_map[i + 1][1]:
                return i
        return l - 1

    all_text = "".join(p[2] for p in page_map)
    length = len(all_text)
    start = 0
    end = length
    while start + SECTION_OVERLAP < length:
        last_word = -1
        end = start + MAX_SECTION_LENGTH

        if end > length:
            end = length
        else:
            while end < length and (end - start - MAX_SECTION_LENGTH) < SENTENCE_SEARCH_LIMIT and all_text[end] not in SENTENCE_ENDINGS:
                if all_text[end] in WORDS_BREAKS:
                    last_word = end
                end += 1
            if end < length and all_text[end] not in SENTENCE_ENDINGS and last_word > 0:
                end = last_word
        if end < length:
            end += 1

        last_word = -1
        while start > 0 and start > end - MAX_SECTION_LENGTH - 2 * SENTENCE_SEARCH_LIMIT and all_text[start] not in SENTENCE_ENDINGS:
            if all_text[start] in WORDS_BREAKS:
                last_word = start
            start -= 1
        if all_text[start] not in SENTENCE_ENDINGS and last_word > 0:
            start = last_word
        if start > 0:
            start += 1

        section_text = all_text[start:end]
        yield (section_text, find_page(start))

        last_table_start = section_text.rfind("<table")
        if (last_table_start > 2 * SENTENCE_SEARCH_LIMIT and last_table_start > section_text.rfind("</table")):
            if verbose: print(f"Section ends with unclosed table, starting next section with the table at page {find_page(start)} offset {start} table start {last_table_start}")
            start = min(end - SECTION_OVERLAP, start + last_table_start)
        else:
            start = end - SECTION_OVERLAP

    if start + SECTION_OVERLAP < end:
        yield (all_text[start:end], find_page(start))

# %%
def create_sections(filename, page_map):
    for i, (section, pagenum) in enumerate(split_text(page_map)):
        yield {
            "id": re.sub("[^0-9a-zA-Z_-]","_",f"{filename}-{i}"),
            "content": section,
            "category": category,
            "sourcepage": blob_name_from_file_page(filename, pagenum),
            "sourcefile": filename
        }

# %%
def index_sections(filename, sections):
    if verbose:
        print(f"Indexing sections from '{filename}' into search index '{index}'")
        
    search_client = SearchClient(endpoint=f"https://{searchservice}.search.windows.net/",
                                index_name=index,
                                credential=search_creds)
    
    i = 0
    batch = []
    
    for s in sections:
        # Assuming 's' is a dictionary where 'content' is the text content
        doc = {
            "text": s.get("content", "")  # Replace 'content' with the correct field name
            # Add other fields as needed based on your index schema
        }
        batch.append(doc)
        i += 1
        
        # Upload batch every 1000 sections
        if i % 1000 == 0:
            try:
                results = search_client.upload_documents(documents=batch)
                succeeded = sum(1 for r in results if r.succeeded)
                if verbose:
                    print(f"\tIndexed {len(results)} sections, {succeeded} succeeded")
                batch = []  # Clear batch after successful upload
            except Exception as e:
                print(f"Error uploading batch: {e}")
                # Handle or log the exception as needed
        
    # Upload any remaining sections in the last batch
    if len(batch) > 0:
        try:
            results = search_client.upload_documents(documents=batch)
            succeeded = sum(1 for r in results if r.succeeded)
            if verbose:
                print(f"\tIndexed {len(results)} sections, {succeeded} succeeded")
        except Exception as e:
            print(f"Error uploading final batch: {e}")
            # Handle or log the exception as needed

# %%
def remove_from_index(filename):
    if verbose: print(f"Removing sections from '{filename or '<all>'}' from search index '{index}'")
    search_client = SearchClient(endpoint=f"https://{searchservice}.search.windows.net/",
                                    index_name=index,
                                    credential=search_creds)
    while True:
        filter = None if filename == None else f"sourcefile eq '{os.path.basename(filename)}'"
        r = search_client.search("", filter=filter, top=1000, include_total_count=True)
        if r.get_count() == 0:
            break
        r = search_client.delete_documents(documents=[{ "id": d["id"] } for d in r])
        if verbose: print(f"\tRemoved {len(r)} sections from index")
        # It can take a few seconds for search results to reflect changes, so wait a bit
        time.sleep(2)

# %%
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import SearchIndex, SimpleField, SearchableField, SemanticSearch, SemanticConfiguration, SemanticPrioritizedFields, SemanticField
from azure.core.credentials import AzureKeyCredential
import requests

def create_search_index():
    
    if verbose: print(f"Ensuring search index {index} exists")
    
    endpoint = f"https://{searchservice}.search.windows.net"
    
    if verbose:
        print(f"Search service: {searchservice}")
        print(f"Endpoint: {endpoint}")
        print(f"Credentials: {search_creds}")
    
    index_client = SearchIndexClient(endpoint=endpoint, credential=search_creds)
    
    if index not in index_client.list_index_names():
        search_index = SearchIndex(
            name=index,
            fields=[
                SimpleField(name="id", type="Edm.String", key=True),
                SearchableField(name="content", type="Edm.String", analyzer_name="en.microsoft"),
                SimpleField(name="category", type="Edm.String", filterable=True, facetable=True),
                SimpleField(name="sourcepage", type="Edm.String", filterable=True, facetable=True),
                SimpleField(name="sourcefile", type="Edm.String", filterable=True, facetable=True)
            ],
            semantic_settings=SemanticSearch(
                configurations=[SemanticConfiguration(
                    name='default',
                    prioritized_fields=SemanticPrioritizedFields(
                        title_field=None, prioritized_content_fields=[SemanticField(field_name='content')]))])
        )
        if verbose: print(f"Creating {index} search index")
        index_client.create_index(search_index)
    else:
        if verbose: print(f"Search index {index} already exists")

# %%
create_search_index()
# Out:
# Ensuring search index rag-index-searcher exists
# Search service: rag-workspace
# Endpoint: https://rag-workspace.search.windows.net
# Credentials: <azure.core.credentials.AzureKeyCredential object at 0x7f91da462b10>
# Search index rag-index-searcher already exists

# %%
FILE_PATH
# Out:
# 'Docs-for-RAG/'

# %%
for filename in glob.glob(FILE_PATH + "/*.pdf"):
    if verbose: print(f"Processing '{filename}'")
    upload_blobs(filename)
    page_map = get_document_text(filename)
    sections = create_sections(filename, page_map)
# Out:
# Processing 'Docs-for-RAG/NVIDIA-2024-Annual-Report.pdf'
# 	Uploading blob for page 0 -> NVIDIA-2024-Annual-Report-0.pdf
# 	Uploading blob for page 1 -> NVIDIA-2024-Annual-Report-1.pdf
# 	Uploading blob for page 2 -> NVIDIA-2024-Annual-Report-2.pdf
# 	Uploading blob for page 3 -> NVIDIA-2024-Annual-Report-3.pdf
# 	Uploading blob for page 4 -> NVIDIA-2024-Annual-Report-4.pdf
# 	Uploading blob for page 5 -> NVIDIA-2024-Annual-Report-5.pdf
# 	Uploading blob for page 6 -> NVIDIA-2024-Annual-Report-6.pdf
# 	Uploading blob for page 7 -> NVIDIA-2024-Annual-Report-7.pdf
# 	Uploading blob for page 8 -> NVIDIA-2024-Annual-Report-8.pdf
# 	Uploading blob for page 9 -> NVIDIA-2024-Annual-Report-9.pdf
# 	Uploading blob for page 10 -> NVIDIA-2024-Annual-Report-10.pdf
# 	Uploading blob for page 11 -> NVIDIA-2024-Annual-Report-11.pdf
# 	Uploading blob for page 12 -> NVIDIA-2024-Annual-Report-12.pdf
# 	Uploading blob for page 13 -> NVIDIA-2024-Annual-Report-13.pdf
# 	Uploading blob for page 14 -> NVIDIA-2024-Annual-Report-14.pdf
# 	Uploading blob for page 15 -> NVIDIA-2024-Annual-Report-15.pdf
# 	Uploading blob for page 16 -> NVIDIA-2024-Annual-Report-16.pdf
# 	Uploading blob for page 17 -> NVIDIA-2024-Annual-Report-17.pdf
# 	Uploading blob for page 18 -> NVIDIA-2024-Annual-Report-18.pdf
# 	Uploading blob for page 19 -> NVIDIA-2024-Annual-Report-19.pdf
# 	Uploading blob for page 20 -> NVIDIA-2024-Annual-Report-20.pdf
# 	Uploading blob for page 21 -> NVIDIA-2024-Annual-Report-21.pdf
# 	Uploading blob for page 22 -> NVIDIA-2024-Annual-Report-22.pdf
# 	Uploading blob for page 23 -> NVIDIA-2024-Annual-Report-23.pdf
# 	Uploading blob for page 24 -> NVIDIA-2024-Annual-Report-24.pdf
# 	Uploading blob for page 25 -> NVIDIA-2024-Annual-Report-25.pdf
# 	Uploading blob for page 26 -> NVIDIA-2024-Annual-Report-26.pdf
# 	Uploading blob for page 27 -> NVIDIA-2024-Annual-Report-27.pdf
# 	Uploading blob for page 28 -> NVIDIA-2024-Annual-Report-28.pdf
# 	Uploading blob for page 29 -> NVIDIA-2024-Annual-Report-29.pdf
# 	Uploading blob for page 30 -> NVIDIA-2024-Annual-Report-30.pdf
# 	Uploading blob for page 31 -> NVIDIA-2024-Annual-Report-31.pdf
# 	Uploading blob for page 32 -> NVIDIA-2024-Annual-Report-32.pdf
# 	Uploading blob for page 33 -> NVIDIA-2024-Annual-Report-33.pdf
# 	Uploading blob for page 34 -> NVIDIA-2024-Annual-Report-34.pdf
# 	Uploading blob for page 35 -> NVIDIA-2024-Annual-Report-35.pdf
# 	Uploading blob for page 36 -> NVIDIA-2024-Annual-Report-36.pdf
# 	Uploading blob for page 37 -> NVIDIA-2024-Annual-Report-37.pdf
# 	Uploading blob for page 38 -> NVIDIA-2024-Annual-Report-38.pdf
# 	Uploading blob for page 39 -> NVIDIA-2024-Annual-Report-39.pdf
# 	Uploading blob for page 40 -> NVIDIA-2024-Annual-Report-40.pdf
# 	Uploading blob for page 41 -> NVIDIA-2024-Annual-Report-41.pdf
# 	Uploading blob for page 42 -> NVIDIA-2024-Annual-Report-42.pdf
# 	Uploading blob for page 43 -> NVIDIA-2024-Annual-Report-43.pdf
# 	Uploading blob for page 44 -> NVIDIA-2024-Annual-Report-44.pdf
# 	Uploading blob for page 45 -> NVIDIA-2024-Annual-Report-45.pdf
# 	Uploading blob for page 46 -> NVIDIA-2024-Annual-Report-46.pdf
# 	Uploading blob for page 47 -> NVIDIA-2024-Annual-Report-47.pdf
# 	Uploading blob for page 48 -> NVIDIA-2024-Annual-Report-48.pdf
# 	Uploading blob for page 49 -> NVIDIA-2024-Annual-Report-49.pdf
# 	Uploading blob for page 50 -> NVIDIA-2024-Annual-Report-50.pdf
# 	Uploading blob for page 51 -> NVIDIA-2024-Annual-Report-51.pdf
# 	Uploading blob for page 52 -> NVIDIA-2024-Annual-Report-52.pdf
# 	Uploading blob for page 53 -> NVIDIA-2024-Annual-Report-53.pdf
# 	Uploading blob for page 54 -> NVIDIA-2024-Annual-Report-54.pdf
# 	Uploading blob for page 55 -> NVIDIA-2024-Annual-Report-55.pdf
# 	Uploading blob for page 56 -> NVIDIA-2024-Annual-Report-56.pdf
# 	Uploading blob for page 57 -> NVIDIA-2024-Annual-Report-57.pdf
# 	Uploading blob for page 58 -> NVIDIA-2024-Annual-Report-58.pdf
# 	Uploading blob for page 59 -> NVIDIA-2024-Annual-Report-59.pdf
# 	Uploading blob for page 60 -> NVIDIA-2024-Annual-Report-60.pdf
# 	Uploading blob for page 61 -> NVIDIA-2024-Annual-Report-61.pdf
# 	Uploading blob for page 62 -> NVIDIA-2024-Annual-Report-62.pdf
# 	Uploading blob for page 63 -> NVIDIA-2024-Annual-Report-63.pdf
# 	Uploading blob for page 64 -> NVIDIA-2024-Annual-Report-64.pdf
# 	Uploading blob for page 65 -> NVIDIA-2024-Annual-Report-65.pdf
# 	Uploading blob for page 66 -> NVIDIA-2024-Annual-Report-66.pdf
# 	Uploading blob for page 67 -> NVIDIA-2024-Annual-Report-67.pdf
# 	Uploading blob for page 68 -> NVIDIA-2024-Annual-Report-68.pdf
# 	Uploading blob for page 69 -> NVIDIA-2024-Annual-Report-69.pdf
# 	Uploading blob for page 70 -> NVIDIA-2024-Annual-Report-70.pdf
# 	Uploading blob for page 71 -> NVIDIA-2024-Annual-Report-71.pdf
# 	Uploading blob for page 72 -> NVIDIA-2024-Annual-Report-72.pdf
# 	Uploading blob for page 73 -> NVIDIA-2024-Annual-Report-73.pdf
# 	Uploading blob for page 74 -> NVIDIA-2024-Annual-Report-74.pdf
# 	Uploading blob for page 75 -> NVIDIA-2024-Annual-Report-75.pdf
# 	Uploading blob for page 76 -> NVIDIA-2024-Annual-Report-76.pdf
# 	Uploading blob for page 77 -> NVIDIA-2024-Annual-Report-77.pdf
# 	Uploading blob for page 78 -> NVIDIA-2024-Annual-Report-78.pdf
# 	Uploading blob for page 79 -> NVIDIA-2024-Annual-Report-79.pdf
# 	Uploading blob for page 80 -> NVIDIA-2024-Annual-Report-80.pdf
# 	Uploading blob for page 81 -> NVIDIA-2024-Annual-Report-81.pdf
# 	Uploading blob for page 82 -> NVIDIA-2024-Annual-Report-82.pdf
# 	Uploading blob for page 83 -> NVIDIA-2024-Annual-Report-83.pdf
# 	Uploading blob for page 84 -> NVIDIA-2024-Annual-Report-84.pdf
# 	Uploading blob for page 85 -> NVIDIA-2024-Annual-Report-85.pdf
# 	Uploading blob for page 86 -> NVIDIA-2024-Annual-Report-86.pdf
# 	Uploading blob for page 87 -> NVIDIA-2024-Annual-Report-87.pdf
# 	Uploading blob for page 88 -> NVIDIA-2024-Annual-Report-88.pdf
# 	Uploading blob for page 89 -> NVIDIA-2024-Annual-Report-89.pdf
# 	Uploading blob for page 90 -> NVIDIA-2024-Annual-Report-90.pdf
# 	Uploading blob for page 91 -> NVIDIA-2024-Annual-Report-91.pdf
# 	Uploading blob for page 92 -> NVIDIA-2024-Annual-Report-92.pdf
# 	Uploading blob for page 93 -> NVIDIA-2024-Annual-Report-93.pdf
# 	Uploading blob for page 94 -> NVIDIA-2024-Annual-Report-94.pdf
# 	Uploading blob for page 95 -> NVIDIA-2024-Annual-Report-95.pdf
# 	Uploading blob for page 96 -> NVIDIA-2024-Annual-Report-96.pdf
# 	Uploading blob for page 97 -> NVIDIA-2024-Annual-Report-97.pdf
# 	Uploading blob for page 98 -> NVIDIA-2024-Annual-Report-98.pdf
# 	Uploading blob for page 99 -> NVIDIA-2024-Annual-Report-99.pdf
# 	Uploading blob for page 100 -> NVIDIA-2024-Annual-Report-100.pdf
# 	Uploading blob for page 101 -> NVIDIA-2024-Annual-Report-101.pdf
# 	Uploading blob for page 102 -> NVIDIA-2024-Annual-Report-102.pdf
# 	Uploading blob for page 103 -> NVIDIA-2024-Annual-Report-103.pdf
# 	Uploading blob for page 104 -> NVIDIA-2024-Annual-Report-104.pdf
# 	Uploading blob for page 105 -> NVIDIA-2024-Annual-Report-105.pdf
# 	Uploading blob for page 106 -> NVIDIA-2024-Annual-Report-106.pdf
# 	Uploading blob for page 107 -> NVIDIA-2024-Annual-Report-107.pdf
# 	Uploading blob for page 108 -> NVIDIA-2024-Annual-Report-108.pdf
# 	Uploading blob for page 109 -> NVIDIA-2024-Annual-Report-109.pdf
# 	Uploading blob for page 110 -> NVIDIA-2024-Annual-Report-110.pdf
# 	Uploading blob for page 111 -> NVIDIA-2024-Annual-Report-111.pdf
# 	Uploading blob for page 112 -> NVIDIA-2024-Annual-Report-112.pdf
# 	Uploading blob for page 113 -> NVIDIA-2024-Annual-Report-113.pdf
# 	Uploading blob for page 114 -> NVIDIA-2024-Annual-Report-114.pdf
# 	Uploading blob for page 115 -> NVIDIA-2024-Annual-Report-115.pdf
# 	Uploading blob for page 116 -> NVIDIA-2024-Annual-Report-116.pdf
# 	Uploading blob for page 117 -> NVIDIA-2024-Annual-Report-117.pdf
# 	Uploading blob for page 118 -> NVIDIA-2024-Annual-Report-118.pdf
# 	Uploading blob for page 119 -> NVIDIA-2024-Annual-Report-119.pdf
# 	Uploading blob for page 120 -> NVIDIA-2024-Annual-Report-120.pdf
# 	Uploading blob for page 121 -> NVIDIA-2024-Annual-Report-121.pdf
# 	Uploading blob for page 122 -> NVIDIA-2024-Annual-Report-122.pdf
# 	Uploading blob for page 123 -> NVIDIA-2024-Annual-Report-123.pdf
# 	Uploading blob for page 124 -> NVIDIA-2024-Annual-Report-124.pdf
# 	Uploading blob for page 125 -> NVIDIA-2024-Annual-Report-125.pdf
# 	Uploading blob for page 126 -> NVIDIA-2024-Annual-Report-126.pdf
# 	Uploading blob for page 127 -> NVIDIA-2024-Annual-Report-127.pdf
# 	Uploading blob for page 128 -> NVIDIA-2024-Annual-Report-128.pdf
# 	Uploading blob for page 129 -> NVIDIA-2024-Annual-Report-129.pdf
# 	Uploading blob for page 130 -> NVIDIA-2024-Annual-Report-130.pdf
# 	Uploading blob for page 131 -> NVIDIA-2024-Annual-Report-131.pdf
# 	Uploading blob for page 132 -> NVIDIA-2024-Annual-Report-132.pdf
# 	Uploading blob for page 133 -> NVIDIA-2024-Annual-Report-133.pdf
# 	Uploading blob for page 134 -> NVIDIA-2024-Annual-Report-134.pdf
# 	Uploading blob for page 135 -> NVIDIA-2024-Annual-Report-135.pdf
# 	Uploading blob for page 136 -> NVIDIA-2024-Annual-Report-136.pdf
# 	Uploading blob for page 137 -> NVIDIA-2024-Annual-Report-137.pdf
# 	Uploading blob for page 138 -> NVIDIA-2024-Annual-Report-138.pdf
# 	Uploading blob for page 139 -> NVIDIA-2024-Annual-Report-139.pdf
# 	Uploading blob for page 140 -> NVIDIA-2024-Annual-Report-140.pdf
# 	Uploading blob for page 141 -> NVIDIA-2024-Annual-Report-141.pdf
# 	Uploading blob for page 142 -> NVIDIA-2024-Annual-Report-142.pdf
# 	Uploading blob for page 143 -> NVIDIA-2024-Annual-Report-143.pdf
# 	Uploading blob for page 144 -> NVIDIA-2024-Annual-Report-144.pdf
# 	Uploading blob for page 145 -> NVIDIA-2024-Annual-Report-145.pdf
# 	Uploading blob for page 146 -> NVIDIA-2024-Annual-Report-146.pdf
# 	Uploading blob for page 147 -> NVIDIA-2024-Annual-Report-147.pdf
# 	Uploading blob for page 148 -> NVIDIA-2024-Annual-Report-148.pdf
# 	Uploading blob for page 149 -> NVIDIA-2024-Annual-Report-149.pdf
# 	Uploading blob for page 150 -> NVIDIA-2024-Annual-Report-150.pdf
# 	Uploading blob for page 151 -> NVIDIA-2024-Annual-Report-151.pdf
# 	Uploading blob for page 152 -> NVIDIA-2024-Annual-Report-152.pdf
# 	Uploading blob for page 153 -> NVIDIA-2024-Annual-Report-153.pdf
# 	Uploading blob for page 154 -> NVIDIA-2024-Annual-Report-154.pdf
# 	Uploading blob for page 155 -> NVIDIA-2024-Annual-Report-155.pdf
# 	Uploading blob for page 156 -> NVIDIA-2024-Annual-Report-156.pdf
# 	Uploading blob for page 157 -> NVIDIA-2024-Annual-Report-157.pdf
# 	Uploading blob for page 158 -> NVIDIA-2024-Annual-Report-158.pdf
# 	Uploading blob for page 159 -> NVIDIA-2024-Annual-Report-159.pdf
# 	Uploading blob for page 160 -> NVIDIA-2024-Annual-Report-160.pdf
# 	Uploading blob for page 161 -> NVIDIA-2024-Annual-Report-161.pdf
# 	Uploading blob for page 162 -> NVIDIA-2024-Annual-Report-162.pdf
# 	Uploading blob for page 163 -> NVIDIA-2024-Annual-Report-163.pdf
# 	Uploading blob for page 164 -> NVIDIA-2024-Annual-Report-164.pdf
# 	Uploading blob for page 165 -> NVIDIA-2024-Annual-Report-165.pdf
# 	Uploading blob for page 166 -> NVIDIA-2024-Annual-Report-166.pdf
# 	Uploading blob for page 167 -> NVIDIA-2024-Annual-Report-167.pdf
# 	Uploading blob for page 168 -> NVIDIA-2024-Annual-Report-168.pdf
# 	Uploading blob for page 169 -> NVIDIA-2024-Annual-Report-169.pdf
# 	Uploading blob for page 170 -> NVIDIA-2024-Annual-Report-170.pdf
# 	Uploading blob for page 171 -> NVIDIA-2024-Annual-Report-171.pdf
# 	Uploading blob for page 172 -> NVIDIA-2024-Annual-Report-172.pdf
# 	Uploading blob for page 173 -> NVIDIA-2024-Annual-Report-173.pdf
# 	Uploading blob for page 174 -> NVIDIA-2024-Annual-Report-174.pdf
# 	Uploading blob for page 175 -> NVIDIA-2024-Annual-Report-175.pdf
# 	Uploading blob for page 176 -> NVIDIA-2024-Annual-Report-176.pdf
# 	Uploading blob for page 177 -> NVIDIA-2024-Annual-Report-177.pdf
# 	Uploading blob for page 178 -> NVIDIA-2024-Annual-Report-178.pdf
# 	Uploading blob for page 179 -> NVIDIA-2024-Annual-Report-179.pdf
# 	Uploading blob for page 180 -> NVIDIA-2024-Annual-Report-180.pdf
# 	Uploading blob for page 181 -> NVIDIA-2024-Annual-Report-181.pdf
# 	Uploading blob for page 182 -> NVIDIA-2024-Annual-Report-182.pdf
# 	Uploading blob for page 183 -> NVIDIA-2024-Annual-Report-183.pdf
# 	Uploading blob for page 184 -> NVIDIA-2024-Annual-Report-184.pdf
# 	Uploading blob for page 185 -> NVIDIA-2024-Annual-Report-185.pdf
# 	Uploading blob for page 186 -> NVIDIA-2024-Annual-Report-186.pdf

# %%
index_sections(filename, sections)
# Out:
# Indexing sections from 'Docs-for-RAG/NVIDIA-2024-Annual-Report.pdf' into search index 'rag-index-searcher'
